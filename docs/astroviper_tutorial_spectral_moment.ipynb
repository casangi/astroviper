# %% [markdown]
# # AstroVIPER Spectral Moment Tutorial

# %%
from toolviper.utils.data import download, list_files

download(file="Antennae_North.cal.lsrk.ps.zarr")
# Out:
# [2025-08-15 16:18:50,866]     INFO    viperlog:  Downloading from [cloudflare] ....
#
#   Download List
#  ─────────────────────────────────
#   Antennae_North.cal.lsrk.ps.zarr
# [2025-08-15 16:18:50,869]     INFO    viperlog:  File exists: Antennae_North.cal.lsrk.ps.zarr
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
from toolviper.dask.client import local_client
viper_client = local_client(cores=4, memory_limit="4GB")
viper_client

# import dask
# dask.config.set(scheduler='synchronous')
# Out:
# [2025-08-15 16:18:50,899]     INFO    viperlog:  Module path: /Users/jsteeb/Dropbox/toolviper/src/toolviper
# [2025-08-15 16:18:50,902]  WARNING    viperlog:  It is recommended that the local cache directory be set using the dask_local_dir parameter.
# /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages/distributed/node.py:187: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 53735 instead
#   warnings.warn(
# [2025-08-15 16:18:51,552]     INFO    viperlog:  Client <MenrvaClient: 'tcp://127.0.0.1:53736' processes=4 threads=4, memory=14.90 GiB>
# <MenrvaClient: 'tcp://127.0.0.1:53736' processes=4 threads=4, memory=14.90 GiB>

# %%
ps_store = "Antennae_North.cal.lsrk.split.ps.zarr"

from xradio.measurement_set import open_processing_set

intents = ["OBSERVE_TARGET#ON_SOURCE"]
ps = open_processing_set(ps_store, intents=intents)
ps.xr_ps.summary()
# Out:
#                                 name  \
# 0   Antennae_North.cal.lsrk.split_00
# 1   Antennae_North.cal.lsrk.split_01
# 2   Antennae_North.cal.lsrk.split_02
# 3   Antennae_North.cal.lsrk.split_03
# 4   Antennae_North.cal.lsrk.split_04
# 5   Antennae_North.cal.lsrk.split_05
# 6   Antennae_North.cal.lsrk.split_06
# 7   Antennae_North.cal.lsrk.split_07
# 8   Antennae_North.cal.lsrk.split_08
# 9   Antennae_North.cal.lsrk.split_09
# 10  Antennae_North.cal.lsrk.split_10
# 11  Antennae_North.cal.lsrk.split_11
#
#                                               intents           shape  \
# 0                          [OBSERVE_TARGET#ON_SOURCE]  (20, 45, 8, 2)
# 1                          [OBSERVE_TARGET#ON_SOURCE]  (15, 45, 8, 2)
# 2                          [OBSERVE_TARGET#ON_SOURCE]  (15, 45, 8, 2)
# 3                          [OBSERVE_TARGET#ON_SOURCE]  (20, 55, 8, 2)
# 4                          [OBSERVE_TARGET#ON_SOURCE]  (15, 55, 8, 2)
# 5                          [OBSERVE_TARGET#ON_SOURCE]  (15, 55, 8, 2)
# 6                          [OBSERVE_TARGET#ON_SOURCE]   (5, 55, 8, 2)
# 7                          [OBSERVE_TARGET#ON_SOURCE]   (5, 55, 8, 2)
# 8                          [OBSERVE_TARGET#ON_SOURCE]   (5, 55, 8, 2)
# 9   [OBSERVE_TARGET#ON_SOURCE, CALIBRATE_WVR#ON_SO...  (20, 77, 8, 2)
# 10  [OBSERVE_TARGET#ON_SOURCE, CALIBRATE_WVR#ON_SO...  (15, 77, 8, 2)
# 11  [OBSERVE_TARGET#ON_SOURCE, CALIBRATE_WVR#ON_SO...  (15, 77, 8, 2)
#
#    polarization         scan_name spw_name                    field_name  \
# 0      [XX, YY]   [17, 21, 25, 9]    spw_0  [NGC4038 - Antennae North_0]
# 1      [XX, YY]       [17, 21, 9]    spw_0  [NGC4038 - Antennae North_1]
# 2      [XX, YY]       [17, 21, 9]    spw_0  [NGC4038 - Antennae North_2]
# 3      [XX, YY]  [26, 34, 38, 42]    spw_0  [NGC4038 - Antennae North_0]
# 4      [XX, YY]      [26, 34, 38]    spw_0  [NGC4038 - Antennae North_1]
# 5      [XX, YY]      [26, 34, 38]    spw_0  [NGC4038 - Antennae North_2]
# 6      [XX, YY]              [43]    spw_0  [NGC4038 - Antennae North_0]
# 7      [XX, YY]              [43]    spw_0  [NGC4038 - Antennae North_1]
# 8      [XX, YY]              [43]    spw_0  [NGC4038 - Antennae North_2]
# 9      [XX, YY]  [48, 56, 60, 64]    spw_0  [NGC4038 - Antennae North_0]
# 10     [XX, YY]      [48, 56, 60]    spw_0  [NGC4038 - Antennae North_1]
# 11     [XX, YY]      [48, 56, 60]    spw_0  [NGC4038 - Antennae North_2]
#
#                      source_name line_name  \
# 0   [NGC4038 - Antennae North_0]        []
# 1   [NGC4038 - Antennae North_0]        []
# 2   [NGC4038 - Antennae North_0]        []
# 3   [NGC4038 - Antennae North_0]        []
# 4   [NGC4038 - Antennae North_0]        []
# 5   [NGC4038 - Antennae North_0]        []
# 6   [NGC4038 - Antennae North_0]        []
# 7   [NGC4038 - Antennae North_0]        []
# 8   [NGC4038 - Antennae North_0]        []
# 9   [NGC4038 - Antennae North_0]        []
# 10  [NGC4038 - Antennae North_0]        []
# 11  [NGC4038 - Antennae North_0]        []
#
#                           field_coords  start_frequency  end_frequency
# 0   [fk5, 12h01m52.43s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 1   [fk5, 12h01m52.96s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 2   [fk5, 12h01m53.49s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 3   [fk5, 12h01m52.43s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 4   [fk5, 12h01m52.96s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 5   [fk5, 12h01m53.49s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 6   [fk5, 12h01m52.43s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 7   [fk5, 12h01m52.96s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 8   [fk5, 12h01m53.49s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 9   [fk5, 12h01m52.43s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 10  [fk5, 12h01m52.96s, -18d52m02.92s]     3.439281e+11   3.440067e+11
# 11  [fk5, 12h01m53.49s, -18d52m02.92s]     3.439281e+11   3.440067e+11

# %%
ps.xr_ps.plot_phase_centers()

# %%
import numpy as np
import xarray as xr
import dask
from graphviper.graph_tools.coordinate_utils import make_parallel_coord, make_frequency_coord
from graphviper.graph_tools import map, reduce
from astroviper._domain._image._moment_max import _moment_max
from astroviper.imaging._utils import _make_image
from toolviper.utils.display import dict_to_html
from IPython.display import HTML, display


#ps_store = "Antennae_North.cal.lsrk.split.py39.v3.vis.zarr"
ps_store = "Antennae_North.cal.lsrk.ps.zarr"
intents = ["OBSERVE_TARGET#ON_SOURCE"]
ps = open_processing_set(ps_store, intents=intents)

grid_params = {}
grid_params["chan_mode"] = "cube"
grid_params["image_size"] = [500, 500]
grid_params["cell_size"] = np.array([-0.13, 0.13]) * np.pi / (180 * 3600)
grid_params["fft_padding"] = 1.0

combined_field_and_source_xds = ps.xr_ps.get_combined_field_and_source_xds()
center_field_name = combined_field_and_source_xds.attrs['center_field_name']
grid_params["phase_direction"] = combined_field_and_source_xds.FIELD_PHASE_CENTER_DIRECTION.sel(field_name=center_field_name)

input_params = {}
input_params["grid_params"] = grid_params
input_params["to_disk"] = False
input_params["input_data_store"]=ps_store
input_params["polarization"] = ["XX","YY"]
input_params["time"] = [0]
input_params["frequency"] = None
input_params['data_group'] = "base"

parallel_coords = {}
# coord = make_frequency_coord(
#     freq_start=343018346078.4616,
#     freq_delta=11231488.981445312,
#     n_channels=166,
# )
#coord = ps['Antennae_North.cal.lsrk.split_04'].frequency
coord = ps['Antennae_North.cal.lsrk_34'].frequency

parallel_coords["frequency"] = make_parallel_coord(coord=coord, n_chunks=20)
from graphviper.graph_tools.coordinate_utils import interpolate_data_coords_onto_parallel_coords
node_task_data_mapping = interpolate_data_coords_onto_parallel_coords(parallel_coords, ps)
display(HTML(dict_to_html(node_task_data_mapping)))

import time
graph = map(
    input_data=ps,
    node_task_data_mapping=node_task_data_mapping,
    node_task=_make_image,
    input_params=input_params,
    in_memory_compute=False
)

input_params = {}
viper_graph = reduce(graph, _moment_max, input_params)

from graphviper.graph_tools import generate_dask_workflow
dask_graph = generate_dask_workflow(viper_graph)
# Out:
# <div style='margin-left: 0em;'><details><summary>0</summary><div style='margin-left: 1em;'><strong>chunk_indices:</strong> (np.int64(0),)</div><div style='margin-left: 1em;'><strong>parallel_dims:</strong> ['frequency']</div><div style='margin-left: 1em;'><details><summary>data_selection</summary><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_00</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_01</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_02</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_03</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_04</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_05</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_06</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_07</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_08</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_09</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_10</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_11</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_12</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_13</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_14</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_15</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_16</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_17</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(np.int64(0), np.int64(9), None)</div></details></div><div style='margin-left: 2em;'><details><summary ...

# %%
dask.visualize(dask_graph)

# %%
img_xds = dask.compute(dask_graph)[0]
img_xds
# Out:
# <xarray.Dataset> Size: 40MB
# Dimensions:                    (dummy: 1, frequency: 1, polarization: 2,
#                                 u: 500, v: 500, l: 500, m: 500, time: 1,
#                                 beam_param: 3)
# Coordinates:
#   * time                       (time) float64 8B 0.0
#   * polarization               (polarization) <U2 16B 'XX' 'YY'
#   * l                          (l) float64 4kB 0.0001576 ... -0.0001569
#   * m                          (m) float64 4kB -0.0001576 ... 0.0001569
#     right_ascension            (l, m) float64 2MB 3.15 3.15 3.15 ... 3.15 3.15
#     declination                (l, m) float64 2MB -0.3295 -0.3295 ... -0.3291
#   * beam_param                 (beam_param) <U5 60B 'major' 'minor' 'pa'
# Dimensions without coordinates: dummy, frequency, u, v
# Data variables:
#     APERTURE                   (dummy, frequency, polarization, u, v) complex128 8MB ...
#     APERTURE_NORMALIZATION     (dummy, frequency, polarization) float64 16B 5...
#     UV_SAMPLING                (dummy, frequency, polarization, u, v) complex128 8MB ...
#     UV_SAMPLING_NORMALIZATION  (dummy, frequency, polarization) float64 16B 9...
#     VISIBILITY                 (dummy, frequency, polarization, u, v) complex128 8MB ...
#     VISIBILITY_NORMALIZATION   (dummy, frequency, polarization) float64 16B 5...
#     PRIMARY_BEAM               (dummy, frequency, polarization, l, m) float64 4MB ...
#     POINT_SPREAD_FUNCTION      (dummy, frequency, polarization, l, m) float64 4MB ...
#     SKY                        (dummy, frequency, polarization, l, m) float64 4MB ...

# %%
import matplotlib.pyplot as plt

plt.figure()
img_xds.SKY.isel(polarization=0, frequency=0, dummy=0).plot.imshow(cmap='viridis',vmin=0.0)
plt.figure()
img_xds.PRIMARY_BEAM.isel(polarization=0, frequency=0, dummy=0).plot()

# %%
img_xds.to_zarr("Antennae_North_MOM8.img.zarr", mode="w")
