# %% [markdown]
# # AstroVIPER Spectral Moment Tutorial

# %%
from graphviper.utils.data import download

download(file="Antennae_North.cal.lsrk.vis.zarr")
# Out:
# [2024-03-11 11:16:01,652]     INFO  graphviper:  File exists: Antennae_North.cal.lsrk.vis.zarr

# %%
from graphviper.dask.client import local_client
viper_client = local_client(cores=4, memory_limit="4GB")
viper_client

# import dask
# dask.config.set(scheduler='synchronous')
# Out:
# [2024-03-11 11:16:01,787]     INFO  graphviper:  Checking parameter values for client.local_client
# [2024-03-11 11:16:01,788]     INFO  graphviper:  Module path: /Users/jsteeb/Dropbox/graphviper/
# [2024-03-11 11:16:01,789]     INFO  graphviper:  Searching /Users/jsteeb/Dropbox/graphviper/src/graphviper/config/ for configuration file, please wait ...
# [2024-03-11 11:16:01,797]  WARNING      client:  It is recommended that the local cache directory be set using the dask_local_dir parameter.
# /Users/jsteeb/mambaforge-pypy3/envs/astroviper2/lib/python3.11/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 60605 instead
#   warnings.warn(
# [2024-03-11 11:16:05,209]     INFO      client:  Created client <MenrvaClient: 'tcp://127.0.0.1:60606' processes=4 threads=4, memory=14.90 GiB>
# <MenrvaClient: 'tcp://127.0.0.1:60606' processes=4 threads=4, memory=14.90 GiB>

# %%
ps_name = "Antennae_North.cal.lsrk.vis.zarr"

from xradio.vis.read_processing_set import read_processing_set

fields = ["NGC4038 - Antennae North"]
intents = ["OBSERVE_TARGET#ON_SOURCE"]
ps = read_processing_set(ps_name, intents=intents, fields=fields)
ps.summary()
# Out:
#                                                  name  ddi  \
# 0   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 1   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 2   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 3   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 4   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 5   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 6   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 7   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 8   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 9   Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 10  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 11  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 12  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 13  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 14  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 15  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 16  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 17  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 18  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 19  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 20  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 21  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
# 22  Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_T...    0
#
#                       intent  field_id                field_name  \
# 0   OBSERVE_TARGET#ON_SOURCE        23  NGC4038 - Antennae North
# 1   OBSERVE_TARGET#ON_SOURCE        15  NGC4038 - Antennae North
# 2   OBSERVE_TARGET#ON_SOURCE        12  NGC4038 - Antennae North
# 3   OBSERVE_TARGET#ON_SOURCE         3  NGC4038 - Antennae North
# 4   OBSERVE_TARGET#ON_SOURCE         4  NGC4038 - Antennae North
# 5   OBSERVE_TARGET#ON_SOURCE        13  NGC4038 - Antennae North
# 6   OBSERVE_TARGET#ON_SOURCE        14  NGC4038 - Antennae North
# 7   OBSERVE_TARGET#ON_SOURCE        22  NGC4038 - Antennae North
# 8   OBSERVE_TARGET#ON_SOURCE         5  NGC4038 - Antennae North
# 9   OBSERVE_TARGET#ON_SOURCE         2  NGC4038 - Antennae North
# 10  OBSERVE_TARGET#ON_SOURCE         9  NGC4038 - Antennae North
# 11  OBSERVE_TARGET#ON_SOURCE         7  NGC4038 - Antennae North
# 12  OBSERVE_TARGET#ON_SOURCE        20  NGC4038 - Antennae North
# 13  OBSERVE_TARGET#ON_SOURCE        18  NGC4038 - Antennae North
# 14  OBSERVE_TARGET#ON_SOURCE        11  NGC4038 - Antennae North
# 15  OBSERVE_TARGET#ON_SOURCE        16  NGC4038 - Antennae North
# 16  OBSERVE_TARGET#ON_SOURCE         1  NGC4038 - Antennae North
# 17  OBSERVE_TARGET#ON_SOURCE         6  NGC4038 - Antennae North
# 18  OBSERVE_TARGET#ON_SOURCE         8  NGC4038 - Antennae North
# 19  OBSERVE_TARGET#ON_SOURCE        17  NGC4038 - Antennae North
# 20  OBSERVE_TARGET#ON_SOURCE        10  NGC4038 - Antennae North
# 21  OBSERVE_TARGET#ON_SOURCE        19  NGC4038 - Antennae North
# 22  OBSERVE_TARGET#ON_SOURCE        21  NGC4038 - Antennae North
#
#     start_frequency  end_frequency
# 0      3.430183e+11   3.448715e+11
# 1      3.430183e+11   3.448715e+11
# 2      3.430183e+11   3.448715e+11
# 3      3.430183e+11   3.448715e+11
# 4      3.430183e+11   3.448715e+11
# 5      3.430183e+11   3.448715e+11
# 6      3.430183e+11   3.448715e+11
# 7      3.430183e+11   3.448715e+11
# 8      3.430183e+11   3.448715e+11
# 9      3.430183e+11   3.448715e+11
# 10     3.430183e+11   3.448715e+11
# 11     3.430183e+11   3.448715e+11
# 12     3.430183e+11   3.448715e+11
# 13     3.430183e+11   3.448715e+11
# 14     3.430183e+11   3.448715e+11
# 15     3.430183e+11   3.448715e+11
# 16     3.430183e+11   3.448715e+11
# 17     3.430183e+11   3.448715e+11
# 18     3.430183e+11   3.448715e+11
# 19     3.430183e+11   3.448715e+11
# 20     3.430183e+11   3.448715e+11
# 21     3.430183e+11   3.448715e+11
# 22     3.430183e+11   3.448715e+11

# %%
import numpy as np
import xarray as xr
import dask
from graphviper.graph_tools.coordinate_utils import make_parallel_coord, make_frequency_coord
from graphviper.graph_tools import map, reduce
from astroviper._domain._image._moment_max import _moment_max
from astroviper.imaging._utils import _make_image
from graphviper.utils.display import dict_to_html
from IPython.display import HTML, display


ps_name = "Antennae_North.cal.lsrk.vis.zarr"
intents = ["OBSERVE_TARGET#ON_SOURCE"]
ps = read_processing_set(ps_name, intents=intents)
ms_xds = ps.get(0)

grid_params = {}
grid_params["chan_mode"] = "cube"
grid_params["image_size"] = [500, 500]
grid_params["cell_size"] = np.array([-0.13, 0.13]) * np.pi / (180 * 3600)
grid_params["fft_padding"] = 1.0
grid_params["phase_direction"] = ps[
    "Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_12"
].VISIBILITY.attrs["field_info"]["phase_direction"]
grid_params["polarization"] = ms_xds.polarization
grid_params["frequency"] = None
grid_params["time"] = [0]
input_params = {}
input_params["grid_params"] = grid_params
input_params["to_disk"] = False
input_params["input_data_store"]=ps_name

parallel_coords = {}
coord = make_frequency_coord(
    freq_start=343018346078.4616,
    freq_delta=11231488.981445312,
    n_channels=166,
)
parallel_coords["frequency"] = make_parallel_coord(coord=coord, n_chunks=20)
from graphviper.graph_tools.coordinate_utils import interpolate_data_coords_onto_parallel_coords
node_task_data_mapping = interpolate_data_coords_onto_parallel_coords(parallel_coords, ps)
display(HTML(dict_to_html(node_task_data_mapping)))

import time
graph = map(
    input_data=ps,
    node_task_data_mapping=node_task_data_mapping,
    node_task=_make_image,
    input_params=input_params,
    in_memory_compute=False
)

input_params = {}
viper_graph = reduce(graph, _moment_max, input_params)

from graphviper.graph_tools import generate_dask_workflow
dask_graph = generate_dask_workflow(viper_graph)
# Out:
# <div style='margin-left: 0em;'><details><summary>0</summary><div style='margin-left: 1em;'><strong>chunk_indices:</strong> (0,)</div><div style='margin-left: 1em;'><strong>parallel_dims:</strong> ['frequency']</div><div style='margin-left: 1em;'><details><summary>data_selection</summary><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_23</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_15</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_12</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_3</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_4</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_13</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_14</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_22</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_5</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_2</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_9</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_7</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_20</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_18</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_11</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_16</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(0, 9, None)</div></details></div><div style='margin-left: 2em;'><detail ...
#  3.43063272e+11 3.43074504e+11 3.43085735e+11 3.43096967e+11
#  3.43108198e+11]</div><div style='margin-left: 3em;'><strong>dims:</strong> frequency</div><div style='margin-left: 3em;'><details><summary>attrs</summary><div style='margin-left: 4em;'><strong>units:</strong> Hz</div><div style='margin-left: 4em;'><strong>type:</strong> spectral_coord</div><div style='margin-left: 4em;'><strong>velocity_frame:</strong> lsrk</div></details></div></details></div></details></div></details></div><div style='margin-left: 0em;'><details><summary>1</summary><div style='margin-left: 1em;'><strong>chunk_indices:</strong> (1,)</div><div style='margin-left: 1em;'><strong>parallel_dims:</strong> ['frequency']</div><div style='margin-left: 1em;'><details><summary>data_selection</summary><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_23</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_15</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_12</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_3</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_4</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div><div style='margin-left: 2em;'><details><summary>Antennae_North.cal.lsrk_ddi_0_intent_OBSERVE_TARGET#ON_SOURCE_field_id_13</summary><div style='margin-left: 3em;'><strong>frequency:</strong> slice(9, 18, None)</div></details></div

# %%
dask.visualize(dask_graph)

# %%
img_xds = dask.compute(dask_graph)[0][0]
img_xds
# Out:
# <xarray.Dataset>
# Dimensions:                    (polarization: 2, time: 1, l: 500, m: 500,
#                                 dummy: 1, frequency: 1, u: 500, v: 500)
# Coordinates:
#   * polarization               (polarization) <U2 'XX' 'YY'
#   * time                       (time) float64 0.0
#   * l                          (l) float64 0.0001576 0.0001569 ... -0.0001569
#   * m                          (m) float64 -0.0001576 -0.0001569 ... 0.0001569
#     right_ascension            (l, m) float64 3.15 3.15 3.15 ... 3.15 3.15 3.15
#     declination                (l, m) float64 -0.3295 -0.3295 ... -0.3291
# Dimensions without coordinates: dummy, frequency, u, v
# Data variables:
#     APERTURE                   (dummy, polarization, frequency, u, v) complex128 ...
#     APERTURE_NORMALIZATION     (dummy, polarization, frequency) float64 3.158...
#     UV_SAMPLING                (dummy, polarization, frequency, u, v) complex128 ...
#     UV_SAMPLING_NORMALIZATION  (dummy, polarization, frequency) float64 5.914...
#     VISIBILITY                 (dummy, polarization, frequency, u, v) complex128 ...
#     VISIBILITY_NORMALIZATION   (dummy, polarization, frequency) float64 3.156...
#     PRIMARY_BEAM               (dummy, polarization, frequency, l, m) float64 ...
#     POINT_SPREAD_FUNCTION      (dummy, polarization, frequency, l, m) float64 ...
#     SKY                        (dummy, polarization, frequency, l, m) float64 ...

# %%
import matplotlib.pyplot as plt

plt.figure()
img_xds.SKY.isel(polarization=0, frequency=0, dummy=0).plot.imshow(cmap='viridis',vmin=0.0)
plt.figure()
img_xds.PRIMARY_BEAM.isel(polarization=0, frequency=0, dummy=0).plot()

# %%
img_xds.to_zarr("Antennae_North_MOM8.img.zarr", mode="w")
