# %% [markdown]
# # Hogbom Deconvolve Demonstrator
#
# [Colab Link](https://colab.research.google.com/github/casangi/astroviper/blob/main/docs/core_tutorials/imaging/hogbom_clean.ipynb)
#
# This notebook demonstrates the implementation of Hogbom clean within the astroviper framework.
# CASA is used to generate the initial set of images (residual, PSF). The CASA task `deconvolve` is run to deconvolve the residual image. astroviper Hogbom is also run on a copy of the same images, and the two outputs are compared.
#
# This notebook is organized into three sections : The first section runs the CASA deconvolution, the second the astroviper deconvolution, and finally the comparison images and plots.
#
# This has to be done, because importing CASA alongside xradio causes some namespace conflicts and segmentation faults, so once we are done with all the CASA functionality, we will import the astroviper libraries.

# %% [markdown]
# ## Install AstroVIPER
#
# Skip this cell if you don't want to install the latest version of AstroVIPER.

# %%
from importlib.metadata import version
import os

try:
    os.system("pip install --upgrade astroviper")
    os.system("pip install python-casacore")
    import astroviper

    print("Using astroviper version", version("astroviper"))

except ImportError as exc:
    print(f"Could not import astroviper: {exc}")
# Out:
# Requirement already satisfied: astroviper in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (0.0.29)
# Requirement already satisfied: graphviper>=0.0.34 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from astroviper) (0.0.35)
# Requirement already satisfied: numpy>=1.20.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from astroviper) (2.2.6)
# Requirement already satisfied: xradio>=0.0.58 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from astroviper) (0.0.59)
# Requirement already satisfied: astropy in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (7.1.0)
# Requirement already satisfied: toolviper>=0.0.12 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (0.0.16)
# Requirement already satisfied: numba>=0.57.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (0.61.2)
# Requirement already satisfied: s3fs in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (2025.5.1)
# Requirement already satisfied: scipy in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (1.15.3)
# Requirement already satisfied: xarray in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (2025.6.1)
# Requirement already satisfied: zarr<3,>=2 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (2.18.7)
# Requirement already satisfied: pyarrow in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (20.0.0)
# Requirement already satisfied: typeguard in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (4.4.4)
# Requirement already satisfied: numcodecs<0.16 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (0.15.1)
# Requirement already satisfied: psutil in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xradio>=0.0.58->astroviper) (7.0.0)
# Requirement already satisfied: deprecated in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from numcodecs<0.16->xradio>=0.0.58->astroviper) (1.2.18)
# Requirement already satisfied: asciitree in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from zarr<3,>=2->xradio>=0.0.58->astroviper) (0.3.3)
# Requirement already satisfied: fasteners in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from zarr<3,>=2->xradio>=0.0.58->astroviper) (0.19)
# Requirement already satisfied: llvmlite<0.45,>=0.44.0dev0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from numba>=0.57.0->xradio>=0.0.58->astroviper) (0.44.0)
# Requirement already satisfied: cerberus in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (1.3.7)
# Requirement already satisfied: dask>=2025.7.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2025.7.0)
# Requirement already satisfied: dask_jobqueue in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (0.9.0)
# Requirement already satisfied: distributed in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2025.7.0)
# Requirement already satisfied: rich in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (14.0.0)
# Requirement already satisfied: requests in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2.32.4)
# Requirement already satisfied: tqdm in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from toolviper>=0.0.12->xradio>=0.0.58->astroviper) (4.67.1)
# Requirement already satisfied: click>=8.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (8.2.1)
# Requirement already satisfied: cloudpickle>=3.0.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.1.1)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2025.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (25.0)
# Requirement already satisfied: partd>=1.4.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (1.0.0)
# Requirement already satisfied: locket in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from partd>=1.4.0->dask>=2025.7.0->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (1.0.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from astropy->xradio>=0.0.58->astroviper) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2025.4.28.0.37.27 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from astropy->xradio>=0.0.58->astroviper) (0.2025.6.16.0.38.47)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.1.6)
# Requirement already satisfied: msgpack>=1.0.2 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (1.1.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.1.0)
# Requirement already satisfied: tornado>=6.2.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (6.5.1)
# Requirement already satisfied: urllib3>=1.26.5 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2.5.0)
# Requirement already satisfied: zict>=3.0.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from jinja2>=2.10.3->distributed->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.0.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from deprecated->numcodecs<0.16->xradio>=0.0.58->astroviper) (1.17.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from requests->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from requests->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from requests->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2025.6.15)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from rich->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from rich->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->toolviper>=0.0.12->xradio>=0.0.58->astroviper) (0.1.2)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from s3fs->xradio>=0.0.58->astroviper) (2.23.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from s3fs->xradio>=0.0.58->astroviper) (3.12.13)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (0.12.0)
# Requirement already satisfied: botocore<1.38.28,>=1.38.23 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (1.38.27)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (2.9.0.post0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (6.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (1.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->s3fs->xradio>=0.0.58->astroviper) (1.20.1)
# Requirement already satisfied: six>=1.5 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from python-dateutil<3.0.0,>=2.1->aiobotocore<3.0.0,>=2.5.4->s3fs->xradio>=0.0.58->astroviper) (1.17.0)
# Requirement already satisfied: typing_extensions>=4.14.0 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from typeguard->xradio>=0.0.58->astroviper) (4.14.0)
# Requirement already satisfied: pandas>=2.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from xarray->xradio>=0.0.58->astroviper) (2.3.1)
# Requirement already satisfied: pytz>=2020.1 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from pandas>=2.1->xarray->xradio>=0.0.58->astroviper) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from pandas>=2.1->xarray->xradio>=0.0.58->astroviper) (2025.2)
# Requirement already satisfied: python-casacore in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (3.7.1)
# Requirement already satisfied: numpy in /Users/jsteeb/miniforge3/envs/zinc/lib/python3.13/site-packages (from python-casacore) (2.2.6)
# Using astroviper version 0.0.29

# %%
# Common imports across all sections

import os
import ssl
import certifi
import urllib
import tarfile 
import glob
import shutil
import numpy as np
import toolviper

# %% [markdown]
# ## Download images via toolviper

# %% [markdown]
# Wipe any images with the same name on disk, and pull the images from the toolviper data repo in order to make the comparison between astroviper hogbom clean and CASA hogbom clean

# %%
def wipe_images(imlist):
    for im in imlist:
        if os.path.exists(im):
            shutil.rmtree(im)

# %%
resid_orig = "refim_point_im.residual"
psf_orig = "refim_point_im.psf"
casa_deconv_resid = "refim_point_im_casa_hogbom_cleaned.residual"

wipe_images([resid_orig, psf_orig, casa_deconv_resid])

# Update data manifest always
toolviper.utils.data.update()
toolviper.utils.data.download([resid_orig, psf_orig, casa_deconv_resid])
# Out:
# [2025-09-16 11:49:59,827]     INFO    viperlog:  Updating file metadata information ...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [2025-09-16 11:50:00,003]     INFO    viperlog:  Module path: /Users/jsteeb/Dropbox/toolviper/src/toolviper
# [2025-09-16 11:50:00,007]     INFO    viperlog:  Downloading from [cloudflare] ....
#
#   Download List
#  ─────────────────────────────────────────────
#   refim_point_im.residual
#   refim_point_im.psf
#   refim_point_im_casa_hogbom_cleaned.residual
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ## NOTE
#
# The progress bars on the toolviper download may not appear complete, which is a bug in the Jupyter display. The files are very small (< 1 MB total) and the download completes relatively rapidly.

# %% [markdown]
# ## Astroviper : Load images, run deconvolution
#
# Import the astroviper and xradio libraries, load the copies of the residual and PSF images generated by CASA, and run deconvolution.

# %%
# Import astroviper libraries
try:
    from xradio.image import load_image
    from astroviper.core.imaging import deconvolution
except ImportError:
    print("Please install the astroviper libraries. This can be done via pip install astroviper, "
          "or cloning the git repository (https://github.com/casangi/astroviper/) and installing "
          "the relevant branch.")


resid_xds = load_image(resid_orig)
psf_xds = load_image(psf_orig)
casa_residual_xds = load_image(casa_deconv_resid)
# Out:
# [2025-09-16 11:50:01,689]     INFO    viperlog:  J2000 found as system reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately
# Successful readonly open of default-locked table refim_point_im.residual: 1 columns, 1 rows
# [2025-09-16 11:50:01,697]     INFO    viperlog:  J2000 found as native reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately
# [2025-09-16 11:50:01,710]     INFO    viperlog:  J2000 found as system reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately
# Successful readonly open of default-locked table refim_point_im.psf: 1 columns, 1 rows
# [2025-09-16 11:50:01,715]     INFO    viperlog:  J2000 found as native reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately
# [2025-09-16 11:50:01,728]     INFO    viperlog:  J2000 found as system reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately
# Successful readonly open of default-locked table refim_point_im_casa_hogbom_cleaned.residual: 1 columns, 1 rows
# [2025-09-16 11:50:01,737]     INFO    viperlog:  J2000 found as native reference frame in CASA image This corresponds to fk5(equinox="j2000") in astropy. Metadata will be written appropriately

# %%
ret, model_image, residual_image = deconvolution.hogbom_clean(resid_xds, psf_xds, deconv_params={'gain':0.1, 'niter':100, 'threshold':0})
# Out:
# [2025-09-16 11:50:01,751]     INFO    viperlog:  Deconvolution parameter 'clean_box' not specified. Using default: (-1, -1, -1, -1)
# [2025-09-16 11:50:01,754]     INFO    viperlog:
# Running Hogbom CLEAN algorithm...
# [2025-09-16 11:50:01,755]     INFO    viperlog:    Iteration 0, pol 0, peak at (128, 128): 1.058718
# [2025-09-16 11:50:01,765]     INFO    viperlog:    Iteration 100, pol 0, peak at (127, 125): 0.006339

# %%
print(np.squeeze(residual_image['SKY'].data).max())
# Out:
# 0.00598746

# %% [markdown]
# ## Results
#
# Compare the results of the astroviper and CASA outputs. Residual images after deconvolution, model images, fractional differences.

# %%
try:
    import holoviews as hv
except ImportError:
    print(f"Please install holoviews. pip install holoviews")
    exit
    
hv.extension('bokeh')
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='17dcbcb0-0bb2-4f54-a70e-92ec7a570792'>
#   <div id="b863aee8-37be-4f83-8c54-c9a75fdaab61" data-root-id="17dcbcb0-0bb2-4f54-a70e-92ec7a570792" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3e140307-f722-45f8-973a-ad3e2af97eb6":{"version":"3.7.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"17dcbcb0-0bb2-4f54-a70e-92ec7a570792"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"501db4f9-0475-4379-96b0-cdec6f282c1c","attributes":{"plot_id":"17dcbcb0-0bb2-4f54-a70e-92ec7a570792","comm_id":"88b6509f74a54b7b938258ec1f8eeba7","client_comm_id":"e8edd5f585f8490093f33dc6befe9335"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"nam ...
#   var render_items = [{"docid":"3e140307-f722-45f8-973a-ad3e2af97eb6","roots":{"17dcbcb0-0bb2-4f54-a70e-92ec7a570792":"b863aee8-37be-4f83-8c54-c9a75fdaab61"},"root_ids":["17dcbcb0-0bb2-4f54-a70e-92ec7a570792"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <a href="https://holoviews.org" target="_blank" title="HoloViews 1.21.0">
#   <img src='...' style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
# </a>
#
#
# <a href="https://bokeh.org" target="_blank" title="Bokeh 3.7.3">
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'>
#   </img>
# </a>
#
#
#
#
#
#
#
# <span style="float: left; margin-left: 5px; line-height: 15px; cursor: pointer; opacity: 0.7;"
#       onmouseover="this.style.opacity='1'"
#       onmouseout="this.style.opacity='0.7'"
#       title="Extension loaded. This cell output contains code that enables plot interactivity, it should not be removed.">ⓘ</span>
# </div>

# %%
img1 = hv.Image(np.squeeze(residual_image['SKY'].values)).opts(tools=['hover'], title='Astroviper residual image', 
                                        width=300, height=300, colorbar=True, clim=(-0.001, 0.1))
img2 = hv.Image(np.squeeze(np.squeeze(casa_residual_xds['SKY'].values))).opts(tools=['hover'], title='CASA residual image', 
                                        width=300, height=300, colorbar=True, clim=(-0.001, 0.1))

diff = np.squeeze(casa_residual_xds['SKY'].values) - np.squeeze(residual_image['SKY'].values)
img3 = hv.Image(diff).opts(tools=['hover'], title='Difference residual image', 
                                        width=500, height=500, colorbar=True)

fracdiff = (np.squeeze(casa_residual_xds['SKY'].values) - np.squeeze(residual_image['SKY'].values))/np.squeeze(casa_residual_xds['SKY'].values)
img4 = hv.Image(fracdiff).opts(tools=['hover'],  title='Fractional difference residual image', 
                                        width=500, height=500, colorbar=True, clim=(-1,1))

# %%
grid = hv.Layout([img1, img2])
grid
# Out:
# :Layout
#    .Image.I  :Image   [x,y]   (z)
#    .Image.II :Image   [x,y]   (z)

# %%
img3
# Out:
# :Image   [x,y]   (z)

# %%
img4
# Out:
# :Image   [x,y]   (z)
