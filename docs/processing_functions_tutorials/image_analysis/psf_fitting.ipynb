# %% [markdown]
# # PSF Gaussian Fitting demo

# %% [markdown]
# [Colab Link](https://colab.research.google.com/github/casangi/astroviper/blob/main/docs/processing_functions_tutorials/image_analysis/psf_fitting.ipynb)
#
# This notebook demonstrates PSF fitting to a 2-D gaussian beam. The fitting code was adopted from https://github.com/casangi/cngi_prototype/blob/master/cngi/image/fit_gaussian.py . This demo uses a CASA PSF image converted into an XRadio image format, then fitting is performed. Simple numerical comparison with the beam parameters stored in the input CASA image are also made.
#
# ---

# %% [markdown]
# ## Install AstroVIPER
#
# Skip this cell if you don't want to install the latest version of AstroVIPER.

# %%
import os
from importlib.metadata import version

try:
    os.system("pip install --upgrade astroviper[all]")

    import astroviper  # noqa: F401 -- availability probe for the pip-install fallback

    print("Using astroviper version", version("astroviper"))

except ImportError as exc:
    print(f"Could not import astroviper: {exc}")

# %% [markdown]
# ## Pseudo Code
#
# xds_image
#
# ```
# point_spread_function_gaussian_fit(xds_image, npix_window, sampling)
#    delta = (l_delta_xds_image, m_delta_xds_image)
#    # isolate the main lobe of every (time, frequency, polarization) slice
#    # and record the largest value found outside it (the maximum sidelobe)
#    main_lobe, blc, trc, max_sidelobe = extract_main_lobe(xds_image, npix_window)
#
#    psf_gaussian_fit_core(xds_image, blc, trc, sampling, delta)
#       # loop over time, chan, pol coordinates
#       for time in xds
#          for chan in xds
#              for pol in xds
#                interpolated_image_to_fit = interpn(xds, npix_window, sampling)
#                fit_param = minimize(beam_chi2, interpolated_image_to_fit)
#                beam_param(time, chan, pol) = fit_param
#
#    xds_new = xds_image.copy with
#        BEAM_FIT_PARAMS_* = beam_param
#        MAX_SIDELOBE_*    = max_sidelobe
#    return xds_new
# ```

# %% [markdown]
# ---
# ## API

# %%
# import psf gaussian fit function
from astroviper.processing_functions.image_analysis.point_spread_function_gaussian_fit import (
    point_spread_function_gaussian_fit,
)

point_spread_function_gaussian_fit?

# %% [markdown]
# ---
# ## Notes
# * The beam parameters (Bmaj, Bmin, PA) are given in radians
# * The maximum sidelobe level is also returned (a fraction of the PSF peak, dimensionless)
# * The specified window is centered on the peak of the image
# * Sidelobes are checked and excluded within the specified window and determine the final fitting window
# * This implementation uses L-BFGS for the minimization algorithm while the CASA C++ implementation uses the Levenberg-Marquardt method.
# * Also the following two types of re-tries of fitting that the CASA implementation has are not implemented.
#   * No retries of fitting by modifying the initial rotation angle when the fit fails
#   * No retries of fitting by increasing the fitting region (by decreasing cutoff = cutoff/1.5) when the fit fails

# %% [markdown]
# ## Install AstroVIPER
#
# This tutorial runs against an already-installed astroviper (for example an editable development checkout). Run the cell below only if you want to install or upgrade astroviper from PyPI.

# %%
from importlib.metadata import version

# This tutorial runs against an already-installed astroviper (e.g. an editable
# development checkout). To install/upgrade from PyPI instead, uncomment the
# two os.system lines below.
# import os
# os.system("pip install --upgrade astroviper")
# os.system("pip install python-casacore")
try:
    import astroviper  # noqa: F401 -- availability probe

    print("Using astroviper version", version("astroviper"))
except ImportError as exc:
    print(f"Could not import astroviper: {exc}")

# %% [markdown]
# ## Download Data

# %% [markdown]
# Download the test CASA PSF image and convert to the XRADIO image

# %%
# use toolviper
import toolviper

toolviper.utils.data.update()

# %%
from toolviper.utils.data import download

download(file="twhya_selfcal_11chans_lsrk_robust_0.5_niter_0.psf")

# %% [markdown]
# ## Import the data and run PSF gaussian fit

# %% [markdown]
# ### Import the CASA image to an XRADIO image data

# %%
from xradio.image import open_image

xds = open_image(
    store="twhya_selfcal_11chans_lsrk_robust_0.5_niter_0.psf",
    chunks={"l": 25, "m": 25, "frequency": 4},
)
# Register a data group describing the variables the fitter reads and writes.
# The input PSF is in POINT_SPREAD_FUNCTION; the CASA-provided reference beam is
# kept in BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION for later comparison.
xds.attrs["data_groups"] = {
    "imaging": {
        "point_spread_function": "POINT_SPREAD_FUNCTION",
        "beam_fit_params_point_spread_function": "BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION",
    }
}
xds

# %% [markdown]
# ### Examine data content

# %%
xds.POINT_SPREAD_FUNCTION

# %%
xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION

# %% [markdown]
# ### Run gaussian fit on the PSF image

# %% [markdown]
# The `point_spread_function_gaussian_fit` function returns a copy of the dataset with two new data variables, registered under a new `test_psf_fit` data group:
#
# * `BEAM_FIT_PARAMS_POINT_TEST_FIT` &mdash; the fitted beam parameters (Bmaj, Bmin, PA)
# * `MAX_SIDELOBE_POINT_TEST_FIT` &mdash; the maximum sidelobe level per (time, frequency, polarization) slice
#
# The original CASA reference beam in `BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION` is left untouched so it can be used for comparison.

# %%
# run psf fitting
# use sampling comparable to one used in CASA (3001 points for x-y matrix)
import time

start_tm = time.time()
res_xds = point_spread_function_gaussian_fit(
    xds,
    image_data_group_in_name="imaging",
    image_data_group_out_name="test_psf_fit",
    image_data_group_out_modified={
        "beam_fit_params_point_spread_function": "BEAM_FIT_PARAMS_POINT_TEST_FIT",
        "max_sidelobe_point_spread_function": "MAX_SIDELOBE_POINT_TEST_FIT",
    },
    npix_window=(41, 41),
    sampling=(55, 55),
)
print(f"time for fitting: {time.time() - start_tm}s")

# %% [markdown]
# ##　Results

# %%
from IPython.display import display

# the fitted beam parameters (Bmaj, Bmin, PA) are stored in radians
display(res_xds["BEAM_FIT_PARAMS_POINT_TEST_FIT"].compute())
# the maximum sidelobe level (a fraction of the PSF peak) for each channel
display(res_xds["MAX_SIDELOBE_POINT_TEST_FIT"].compute())

# %% [markdown]
# ### Plot the input image with the original CASA beam stored in the image for reference

# %%
# select first frequency channel
data_sel = {"time": [0], "polarization": [0], "frequency": [0]}

# %%
import matplotlib.pyplot as plt
import numpy as np

data1 = xds.POINT_SPREAD_FUNCTION.isel(data_sel).squeeze().T
#
fig, ax = plt.subplots(figsize=(8, 8))
data1.plot.pcolormesh(
    x="right_ascension", y="declination", ax=ax, cmap="viridis", add_colorbar=True
)
bmaj = xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.isel(data_sel).values[0, 0, 0][0]
bmin = xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.isel(data_sel).values[0, 0, 0][1]
bpa = np.rad2deg(
    xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.isel(data_sel).values[0, 0, 0][2]
)
print(f"CASA beam parameters: bmaj={bmaj},bmin={bmin}, bpa={bpa}")
from matplotlib.patches import Ellipse

beam = Ellipse(
    (1.40914, -0.636375),
    width=bmaj,
    height=bmin,
    angle=bpa,
    color="red",
    lw=1,
    fill=False,
    zorder=10,  # Ensure the ellipse is drawn on top
)
ax.add_patch(beam)
ax.set_aspect("equal", adjustable="box")
xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.attrs["units"]

# %% [markdown]
# ### Compare the fitting result with one provided in the input image

# %%
# Generate 2D gaussian using xds BEAM data variable
def psf_model(xds, data_sel, beam_param):
    wx, wy, rot = beam_param
    # uncomment the line below for a quick check on the beam parameter
    # print(f"bmaj:{wx}, bmin:{wy}, pa:{rot}")
    l = xds.POINT_SPREAD_FUNCTION.isel(data_sel).l.data
    m = xds.POINT_SPREAD_FUNCTION.isel(data_sel).m.data
    X, Y = np.meshgrid(l, m)
    # adjust rotation angle to one measured from +x axis
    rot = -(np.pi / 2 - rot)
    xp = X * np.cos(rot) + Y * np.sin(rot)
    yp = X * np.sin(rot) - Y * np.cos(rot)
    gaussian = 1.0 * np.exp(-(((xp) / wx) ** 2 + ((yp) / wy) ** 2) / 2.0)
    return gaussian

# %%
# psf model based on the CASA beam parameter
casa_model = psf_model(
    xds,
    data_sel,
    xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.isel(data_sel).values.squeeze(),
)

# %%
# new fit result
model = psf_model(
    xds,
    data_sel,
    res_xds.BEAM_FIT_PARAMS_POINT_TEST_FIT.isel(data_sel).values.squeeze(),
)

# %%
# extract beam parameters (without data selection)
beam_param = res_xds.BEAM_FIT_PARAMS_POINT_TEST_FIT.values
bmajs = beam_param[:, :, :].squeeze().T[0]
bmins = beam_param[:, :, :].squeeze().T[1]
pas = beam_param[:, :, :].squeeze().T[2]
casa_beam_param = xds.BEAM_FIT_PARAMS_POINT_SPREAD_FUNCTION.values
casa_bmajs = casa_beam_param[:, :, :].squeeze().T[0]
casa_bmins = casa_beam_param[:, :, :].squeeze().T[1]
casa_pas = casa_beam_param[:, :, :].squeeze().T[2]

# %%
# plot beam images
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
l = xds.POINT_SPREAD_FUNCTION.isel(data_sel).l.data
m = xds.POINT_SPREAD_FUNCTION.isel(data_sel).m.data
extent = (l[-1], l[0], m[-1], m[0])
im1 = axes[0, 0].imshow(casa_model, extent=extent, origin="lower", cmap="viridis")
plt.colorbar(im1, ax=axes[0, 0])
axes[0, 0].set_title("CASA psf")
im2 = axes[0, 1].imshow(model, extent=extent, origin="lower", cmap="viridis")
plt.colorbar(im2, ax=axes[0, 1])
axes[0, 1].set_title("psf_gaussian_fit")
im3 = axes[0, 2].imshow((model - casa_model), origin="lower", cmap="viridis")
axes[0, 2].set_title("difference (psf_gaussian_fit - CASA psf)")
plt.colorbar(im3, ax=axes[0, 2])
# plot beam parameters across channels
chans = np.arange(beam_param.shape[1])
axes[1, 0].plot(chans, (bmajs - casa_bmajs) / casa_bmajs)
axes[1, 0].set_ylabel("(Bmaj - casaBmaj)/casaBmaj")
axes[1, 0].set_xlabel("channels")
axes[1, 0].set_title("Bmaj relative error")
axes[1, 1].plot(chans, (bmins - casa_bmins) / casa_bmins)
axes[1, 1].set_ylabel("(Bmin - casaBmin)/casaBmin")
axes[1, 1].set_xlabel("channels")
axes[1, 1].set_title("Bmin relative error")
# axes[1,2].plot(chans, (pas - casa_pas)/casa_pas)
axes[1, 2].set_ylabel("(PA - PA_casa)/PA_casa")
axes[1, 2].set_xlabel("channels")
axes[1, 2].set_title("Positon angle relative error")
axes[1, 2].plot(chans, (pas - casa_pas) / casa_pas)
fig.suptitle("Top: chan 0 psf, Bottom: beam parameter comparison for each channel")
plt.show()
